# %%
import pandas as pd

# %%
df = pd.read_csv("estudiantes.csv")

# %%
df
# Out:
#     NOMBRE  EDAD GENERO       CARRERA SEMESTRE
# 0   Victor    28      M     Auditoria  Primero
# 1   Josefa    23      F   Informatica  Primero
# 2     Raul    26      M       Derecho   Quinto
# 3  Mariana    27      F   Informatica  Septimo
# 4  Rodrigo    22      M       Derecho  Tercero
# 5  Gustavo    25      M  Arquitectura  Septimo
# 6     Lucy    23      F   Informatica  Primero
# 7    Sofia    24      F      Economia   Noveno

# %%
df.iloc[1 , 3]
# Out:
# 'Informatica'

# %%
df.iloc[2,:3]
# Out:
# NOMBRE    Raul
# EDAD        26
# GENERO       M
# Name: 2, dtype: object

# %%
df.loc[:3, ("NOMBRE", "CARRERA")]
# Out:
#     NOMBRE      CARRERA
# 0   Victor    Auditoria
# 1   Josefa  Informatica
# 2     Raul      Derecho
# 3  Mariana  Informatica

# %%
# añadimos filas y columnas al dataframe

filaNueva = pd.DataFrame(
    {
        "NOMBRE": ["Carlos"], 
        "EDAD": [27], 
        "GENERO": ["M"], 
        "CARRERA": ["Sociologia"], 
        "TURNO": ["tarde"],
        "SEMESTRE": ["Segundo"]
    }
)


df = pd.concat([df, filaNueva], ignore_index = True)


df
# Out:
#     NOMBRE  EDAD GENERO       CARRERA SEMESTRE  TURNO
# 0   Victor    28      M     Auditoria  Primero    NaN
# 1   Josefa    23      F   Informatica  Primero    NaN
# 2     Raul    26      M       Derecho   Quinto    NaN
# 3  Mariana    27      F   Informatica  Septimo    NaN
# 4  Rodrigo    22      M       Derecho  Tercero    NaN
# 5  Gustavo    25      M  Arquitectura  Septimo    NaN
# 6     Lucy    23      F   Informatica  Primero    NaN
# 7    Sofia    24      F      Economia   Noveno    NaN
# 8   Carlos    27      M    Sociologia  Segundo  tarde
# 9   Carlos    27      M    Sociologia  Segundo  tarde

# %%
# eliminar filas de un dataframe


df.drop([1])
# Out:
#     NOMBRE  EDAD GENERO       CARRERA SEMESTRE  TURNO
# 0   Victor    28      M     Auditoria  Primero    NaN
# 2     Raul    26      M       Derecho   Quinto    NaN
# 3  Mariana    27      F   Informatica  Septimo    NaN
# 4  Rodrigo    22      M       Derecho  Tercero    NaN
# 5  Gustavo    25      M  Arquitectura  Septimo    NaN
# 6     Lucy    23      F   Informatica  Primero    NaN
# 7    Sofia    24      F      Economia   Noveno    NaN
# 8   Carlos    27      M    Sociologia  Segundo  tarde
# 9   Carlos    27      M    Sociologia  Segundo  tarde

# %%
# filtrado de filas de un dataframe


df[(df["GENERO"] == "F")  & (df["EDAD"]  > 22)]
# Out:
#     NOMBRE  EDAD GENERO      CARRERA SEMESTRE TURNO
# 1   Josefa    23      F  Informatica  Primero   NaN
# 3  Mariana    27      F  Informatica  Septimo   NaN
# 6     Lucy    23      F  Informatica  Primero   NaN
# 7    Sofia    24      F     Economia   Noveno   NaN

# %%
df.sort_values("CARRERA")
# Out:
#     NOMBRE  EDAD GENERO       CARRERA SEMESTRE  TURNO
# 5  Gustavo    25      M  Arquitectura  Septimo    NaN
# 0   Victor    28      M     Auditoria  Primero    NaN
# 2     Raul    26      M       Derecho   Quinto    NaN
# 4  Rodrigo    22      M       Derecho  Tercero    NaN
# 7    Sofia    24      F      Economia   Noveno    NaN
# 1   Josefa    23      F   Informatica  Primero    NaN
# 3  Mariana    27      F   Informatica  Septimo    NaN
# 6     Lucy    23      F   Informatica  Primero    NaN
# 8   Carlos    27      M    Sociologia  Segundo  tarde
# 9   Carlos    27      M    Sociologia  Segundo  tarde

# %%
df.sort_values(["EDAD", "CARRERA"], ascending=[True, False])
# Out:
#     NOMBRE  EDAD GENERO       CARRERA SEMESTRE  TURNO
# 4  Rodrigo    22      M       Derecho  Tercero    NaN
# 1   Josefa    23      F   Informatica  Primero    NaN
# 6     Lucy    23      F   Informatica  Primero    NaN
# 7    Sofia    24      F      Economia   Noveno    NaN
# 5  Gustavo    25      M  Arquitectura  Septimo    NaN
# 2     Raul    26      M       Derecho   Quinto    NaN
# 8   Carlos    27      M    Sociologia  Segundo  tarde
# 9   Carlos    27      M    Sociologia  Segundo  tarde
# 3  Mariana    27      F   Informatica  Septimo    NaN
# 0   Victor    28      M     Auditoria  Primero    NaN

# %%
df.dropna()
# Out:
#    NOMBRE  EDAD GENERO     CARRERA SEMESTRE  TURNO
# 8  Carlos    27      M  Sociologia  Segundo  tarde
# 9  Carlos    27      M  Sociologia  Segundo  tarde
